# %% [markdown]
# # **Import Library**

# %%
# !pip install google-play-scraper

# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

import csv
import pandas as pd
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.tencent.ig',          # ID aplikasi
    lang='id',             # Bahasa Indonesia
    country='id',          # Negara Indonesia
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
with open('ulasan_pubg.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
reviews_df = pd.DataFrame(scrapreview)
reviews_df.to_csv('ulasan_pubg.csv', index=False)

reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  155e9195-495b-4517-9c46-186727a42f2a  Pengguna Google
# 1  b7f48138-da4d-4d03-9d3b-2edd04d1ecd4  Pengguna Google
# 2  b29a7057-b121-4698-8606-e9da7b28f1d3  Pengguna Google
# 3  b1cf49da-487d-4fa6-a3c3-c109eee9dae1  Pengguna Google
# 4  83af1722-1b4a-41c2-a88e-e85c381bcdc4  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Mungkin alasan dev-game meluncurkan event even...      3             39
# 1  Saya rasa PUBG dulu Lebih baik dari yang sekar...      5            278
# 2  Ada beberapa yang perlu dikoreksi dari segi uk...      4              9
# 3  masih terdapat banyak bug dalam ingame diantar...      1            189
# 4  Main dari season 3 awal awal masih oke. sinyal...      1              2
#
#   reviewCreatedVersion                  at  \
# 0                3.7.0 2025-04-03 13:14:42
# 1                3.7.0 2025-04-05 03:54:18
# 2                3.7.0 2025-04-05 10:46:21
# 3                3.7.0 2025-04-05 11:53:28
# 4                3.7.0 2025-04-06 18:02:09
#
#                                         replyContent           repliedAt  \
# 0  Pemain yang terhormat,\nKami sangat senang men... 2025-04-05 03:05:41
# 1  Hi pemain! Kami sepenuhnya memahami perasaan A... 2025-04-05 02:57:00
# 2                                               None                 NaT
# 3  Hai pemain! Kami telah memahami masalah yang A... 2025-04-07 07:44:13
# 4  Halo pemain! Terima kasih atas perhatian dan d... 2025-04-07 08:12:18
#
#   appVersion
# 0      3.7.0
# 1      3.7.0
# 2      3.7.0
# 3      3.7.0
# 4      3.7.0
